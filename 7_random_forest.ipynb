# %% [markdown]
# # Random Forest

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Load the data
train = pd.read_csv('data/train_rose.csv')
test = pd.read_csv('data/test.csv')

# %%
X_train = train.drop('CARAVAN', axis=1)
y_train = train['CARAVAN']
X_test = test.drop('CARAVAN', axis=1)
y_test = test['CARAVAN']

# %%
# Define a param grid for the randomForest

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 1000, num = 5)]
# Number of features to consider at every split
max_features = ['sqrt', 'log2']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 50, num = 5)]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf
               }

# %%
cv = RandomizedSearchCV(estimator=RandomForestClassifier(), param_distributions=random_grid, n_iter=100, cv=3, verbose=10, random_state=42, n_jobs=-1)
cv.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV 1/3; 1/100] START max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=600
# [CV 2/3; 1/100] START max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=600
# [CV 3/3; 1/100] START max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=600
# [CV 1/3; 2/100] START max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000
# [CV 2/3; 2/100] START max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000
# [CV 3/3; 2/100] START max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000
# [CV 1/3; 3/100] START max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600
# [CV 2/3; 3/100] START max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600
# [CV 3/3; 1/100] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=600;, score=0.975 total time=  11.2s
# [CV 3/3; 3/100] START max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600
# [CV 1/3; 3/100] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600;, score=0.954 total time=  11.5s
# [CV 1/3; 4/100] START max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200
# [CV 2/3; 3/100] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600;, score=0.960 total time=  11.7s
# [CV 2/3; 4/100] START max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200
# [CV 2/3; 1/100] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=600;, score=0.971 total time=  12.3s
# [CV 3/3; 4/100] START max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200
# [CV 1/3; 1/100] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=600;, score=0.972 total time=  12.4s
# [CV 1/3; 5/100] START max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 1/3; 4/100] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.904 total time=   3.2s
# [CV 2/3; 5/100] START max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 2/3; 4/100] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.907 total time=   3.7s
# [CV 3/3; 5/100] START max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 3/3; 4/100] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.907 total time=   3.3s
# [CV 1/3; 6/100] START max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=600
# [CV 1/3; 5/100] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.960 total time=   3.5s
# [CV 2/3; 6/100] START max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=600
# [CV 1/3; 2/100] END max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.945 total time=  16.4s
# [CV 3/3; 6/100] START max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=600
# [CV 2/3; 2/100] END max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.950 total time=  17.3s
# [CV 1/3; 7/100] START max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 2/3; 5/100] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.968 total time=   3.5s
# [CV 2/3; 7/100] START max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 3/3; 2/100] END max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.951 total time=  18.7s
# [CV 3/3; 7/100] START max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 3/3; 5/100] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.968 total time=   3.6s
# [CV 1/3; 8/100] START max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=600
# [CV 1/3; 7/100] END max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.957 total time=   4.5s
# [CV 2/3; 8/100] START max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=600
# [CV 2/3; 7/100] END max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.968 total time=   5.0s
# [CV 3/3; 8/100] START max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=600
# [CV 3/3; 7/100] END max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.966 total time=   5.1s
# [CV 1/3; 9/100] START max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=800
# [CV 3/3; 3/100] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600;, score=0.960 total time=  12.9s
# [CV 2/3; 9/100] START max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=800
# [CV 1/3; 6/100] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=0.952 total time=  10.6s
# [CV 3/3; 9/100] START max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=800
# [CV 2/3; 6/100] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=0.958 total time=  11.9s
# [CV 1/3; 10/100] START max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600
# [CV 1/3; 8/100] END max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=600;, score=0.946 total time=  11.0s
# [CV 2/3; 10/100] START max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600
# [CV 3/3; 6/100] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=0.962 total time=  13.8s
# [CV 3/3; 10/100] START max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600
# [CV 2/3; 8/100] END max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=600;, score=0.950 total time=  10.9s
# [CV 1/3; 11/100] START max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400
# [CV 3/3; 8/100] END max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=600;, score=0.949 total time=  10.7s
# [CV 2/3; 11/100] START max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400
# [CV 2/3; 9/100] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=800;, score=0.948 total time=  13.6s
# [CV 3/3; 11/100] START max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400
# [CV 1/3; 9/100] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=800;, score=0.943 total time=  14.5s
# [CV 1/3; 12/100] START max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 3/3; 9/100] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=800;, score=0.947 total time=  14.3s
# [CV 2/3; 12/100] START max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 1/3; 11/100] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400;, score=0.944 total time=   8.6s
# [CV 3/3; 12/100] START max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 1/3; 10/100] END max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600;, score=0.958 total time=  13.9s
# [CV 1/3; 13/100] START max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 1/3; 12/100] END max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.951 total time=   3.5s
# [CV 2/3; 13/100] START max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 3/3; 10/100] END max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600;, score=0.961 total time=  13.7s
# [CV 3/3; 13/100] START max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200
# [CV 2/3; 12/100] END max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.961 total time=   3.5s
# [CV 1/3; 14/100] START max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 2/3; 10/100] END max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600;, score=0.963 total time=  14.0s
# [CV 2/3; 14/100] START max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 1/3; 13/100] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.891 total time=   2.5s
# [CV 3/3; 14/100] START max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 2/3; 11/100] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400;, score=0.956 total time=  10.2s
# [CV 1/3; 15/100] START max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400
# [CV 2/3; 13/100] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.897 total time=   2.4s
# [CV 2/3; 15/100] START max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400
# [CV 3/3; 12/100] END max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.959 total time=   3.4s
# [CV 3/3; 15/100] START max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400
# [CV 3/3; 11/100] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400;, score=0.953 total time=   7.9s
# [CV 1/3; 16/100] START max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000
# [CV 3/3; 13/100] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.900 total time=   2.5s
# [CV 2/3; 16/100] START max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000
# [CV 1/3; 14/100] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.966 total time=   3.6s
# [CV 3/3; 16/100] START max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000
# [CV 3/3; 14/100] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.970 total time=   3.9s
# [CV 1/3; 17/100] START max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400
# [CV 2/3; 14/100] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.968 total time=   4.7s
# [CV 2/3; 17/100] START max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400
# [CV 1/3; 15/100] END max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.972 total time=   8.0s
# [CV 3/3; 17/100] START max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400
# [CV 2/3; 15/100] END max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.972 total time=   8.0s
# [CV 1/3; 18/100] START max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 3/3; 15/100] END max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.975 total time=   8.4s
# [CV 2/3; 18/100] START max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 1/3; 18/100] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.903 total time=   2.4s
# [CV 3/3; 18/100] START max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200
# [CV 2/3; 18/100] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.898 total time=   2.5s
# [CV 1/3; 19/100] START max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400
# [CV 1/3; 17/100] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400;, score=0.970 total time=   8.2s
# [CV 2/3; 19/100] START max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400
# [CV 3/3; 18/100] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.900 total time=   2.4s
# [CV 3/3; 19/100] START max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400
# [CV 2/3; 17/100] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400;, score=0.973 total time=   8.4s
# [CV 1/3; 20/100] START max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000
# [CV 3/3; 17/100] END max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=400;, score=0.973 total time=   7.7s
# [CV 2/3; 20/100] START max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000
# [CV 1/3; 19/100] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.885 total time=   5.2s
# [CV 3/3; 20/100] START max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000
# [CV 2/3; 19/100] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.882 total time=   5.0s
# [CV 1/3; 21/100] START max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=800
# [CV 3/3; 19/100] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.900 total time=   4.6s
# [CV 2/3; 21/100] START max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=800
# [CV 1/3; 16/100] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000;, score=0.945 total time=  20.1s
# [CV 3/3; 21/100] START max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=800
# [CV 2/3; 16/100] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000;, score=0.955 total time=  21.7s
# [CV 1/3; 22/100] START max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800
# [CV 3/3; 16/100] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000;, score=0.954 total time=  21.2s
# [CV 2/3; 22/100] START max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800
# [CV 1/3; 21/100] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=800;, score=0.893 total time=   9.8s
# [CV 3/3; 22/100] START max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=800
# [CV 2/3; 21/100] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=800;, score=0.892 total time=  10.3s
# [CV 1/3; 23/100] START max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800
# [CV 1/3; 20/100] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.907 total time=  15.5s
# [CV 2/3; 23/100] START max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800
# [CV 2/3; 20/100] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.905 total time=  14.7s
# [CV 3/3; 23/100] START max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=800
# [CV 3/3; 21/100] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=800;, score=0.901 total time=  10.0s
# [CV 1/3; 24/100] START max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV 3/3; 20/100] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.903 total time=  15.5s
# [CV 2/3; 24/100] START max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=1000
# [CV 1/3; 22/100] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=
END max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.946 total time=  20.2s
# [CV 1/3; 50/100] START max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000
# [CV 3/3; 47/100] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600;, score=0.951 total time=  12.9s
# [CV 2/3; 50/100] START max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000
# [CV 2/3; 47/100] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600;, score=0.956 total time=  14.5s
# [CV 3/3; 50/100] START max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000
# [CV 2/3; 45/100] END max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.957 total time=  23.6s
# [CV 1/3; 51/100] START max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800
# [CV 3/3; 45/100] END max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.955 total time=  22.4s
# [CV 2/3; 51/100] START max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800
# [CV 1/3; 49/100] END max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=800;, score=0.947 total time=  16.2s
# [CV 3/3; 51/100] START max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800
# [CV 2/3; 50/100] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000;, score=0.888 total time=  13.0s
# [CV 1/3; 52/100] START max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 1/3; 50/100] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000;, score=0.887 total time=  13.4s
# [CV 2/3; 52/100] START max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 3/3; 50/100] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=1000;, score=0.899 total time=  12.2s
# [CV 3/3; 52/100] START max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 3/3; 49/100] END max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=800;, score=0.952 total time=  16.8s
# [CV 1/3; 53/100] START max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 2/3; 49/100] END max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=800;, score=0.954 total time=  17.8s
# [CV 2/3; 53/100] START max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 2/3; 51/100] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800;, score=0.909 total time=  11.8s
# [CV 3/3; 53/100] START max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# [CV 1/3; 51/100] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800;, score=0.905 total time=  13.8s
# [CV 1/3; 54/100] START max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=600
# [CV 3/3; 52/100] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.976 total time=   4.9s
# [CV 2/3; 54/100] START max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=600
# [CV 2/3; 52/100] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.972 total time=   5.2s
# [CV 3/3; 54/100] START max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=600
# [CV 1/3; 52/100] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.974 total time=   6.0s
# [CV 1/3; 55/100] START max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400
# [CV 1/3; 53/100] END max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.946 total time=   4.1s
# [CV 2/3; 55/100] START max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400
# [CV 2/3; 53/100] END max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.956 total time=   4.5s
# [CV 3/3; 55/100] START max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400
# [CV 3/3; 53/100] END max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.950 total time=   3.9s
# [CV 1/3; 56/100] START max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV 3/3; 51/100] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=800;, score=0.905 total time=  11.9s
# [CV 2/3; 56/100] START max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV 1/3; 54/100] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=600;, score=0.886 total time=   7.6s
# [CV 3/3; 56/100] START max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV 2/3; 54/100] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=600;, score=0.884 total time=   7.8s
# [CV 1/3; 57/100] START max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000
# [CV 3/3; 54/100] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=600;, score=0.895 total time=   7.8s
# [CV 2/3; 57/100] START max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000
# [CV 1/3; 56/100] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400;, score=0.908 total time=   6.0s
# [CV 3/3; 57/100] START max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000
# [CV 1/3; 55/100] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400;, score=0.945 total time=   7.7s
# [CV 1/3; 58/100] START max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 2/3; 55/100] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400;, score=0.951 total time=   7.5s
# [CV 2/3; 58/100] START max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 2/3; 56/100] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400;, score=0.917 total time=   6.1s
# [CV 3/3; 58/100] START max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 3/3; 55/100] END max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=400;, score=0.950 total time=   7.7s
# [CV 1/3; 59/100] START max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV 1/3; 58/100] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.912 total time=   3.3s
# [CV 2/3; 59/100] START max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV 2/3; 58/100] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.915 total time=   3.0s
# [CV 3/3; 59/100] START max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV 3/3; 58/100] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.917 total time=   3.0s
# [CV 1/3; 60/100] START max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400
# [CV 3/3; 56/100] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400;, score=0.908 total time=   6.9s
# [CV 2/3; 60/100] START max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400
# [CV 1/3; 59/100] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400;, score=0.957 total time=  10.3s
# [CV 3/3; 60/100] START max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400
# [CV 1/3; 60/100] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.947 total time=   8.0s
# [CV 2/3; 59/100] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400;, score=0.964 total time=   8.5s
# [CV 1/3; 61/100] START max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 2/3; 61/100] START max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 3/3; 59/100] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400;, score=0.963 total time=   8.9s
# [CV 3/3; 61/100] START max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 2/3; 60/100] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.954 total time=   9.1s
# [CV 1/3; 62/100] START max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000
# [CV 1/3; 61/100] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.917 total time=   3.0s
# [CV 2/3; 62/100] START max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000
# [CV 2/3; 61/100] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.919 total time=   3.1s
# [CV 3/3; 62/100] START max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000
# [CV 3/3; 61/100] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.920 total time=   3.0s
# [CV 1/3; 63/100] START max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600
# [CV 3/3; 60/100] END max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.953 total time=   8.8s
# [CV 2/3; 63/100] START max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600
# [CV 2/3; 57/100] END max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=1000;, score=0.957 total time=  21.1s
# [CV 3/3; 63/100] START max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600
# ...
# [CV 3/3; 82/100] START max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000
# [CV 3/3; 78/100] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=800;, score=0.968 total time=  19.1s
# [CV 1/3; 83/100] START max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600
# [CV 2/3; 78/100] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=800;, score=0.967 total time=  21.1s
# [CV 2/3; 83/100] START max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600
# [CV 1/3; 81/100] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600;, score=0.943 total time=  12.5s
# [CV 3/3; 83/100] START max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600
# [CV 2/3; 81/100] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600;, score=0.954 total time=  11.7s
# [CV 1/3; 84/100] START max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400
# [CV 3/3; 81/100] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600;, score=0.953 total time=  12.4s
# [CV 2/3; 84/100] START max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400
# [CV 1/3; 84/100] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.903 total time=   4.8s
# [CV 3/3; 84/100] START max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400
# [CV 1/3; 83/100] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=0.912 total time=   9.9s
# [CV 1/3; 85/100] START max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000
# [CV 2/3; 83/100] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=0.918 total time=   9.9s
# [CV 2/3; 85/100] START max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000
# [CV 2/3; 84/100] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.910 total time=   5.3s
# [CV 3/3; 85/100] START max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000
# [CV 3/3; 84/100] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.913 total time=   4.8s
# [CV 1/3; 86/100] START max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600
# [CV 3/3; 83/100] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600;, score=0.912 total time=  10.7s
# [CV 2/3; 86/100] START max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600
# [CV 2/3; 82/100] END max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=0.965 total time=  22.1s
# [CV 3/3; 86/100] START max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600
# [CV 1/3; 82/100] END max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=0.960 total time=  23.6s
# [CV 1/3; 87/100] START max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV 3/3; 82/100] END max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000;, score=0.965 total time=  24.2s
# [CV 2/3; 87/100] START max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV 1/3; 86/100] END max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=0.959 total time=  14.2s
# [CV 3/3; 87/100] START max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400
# [CV 2/3; 86/100] END max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=0.964 total time=  13.7s
# [CV 1/3; 88/100] START max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600
# [CV 1/3; 87/100] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400;, score=0.963 total time=  10.4s
# [CV 2/3; 88/100] START max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600
# [CV 2/3; 87/100] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400;, score=0.969 total time=   9.5s
# [CV 3/3; 88/100] START max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600
# [CV 1/3; 85/100] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=0.958 total time=  24.3s
# [CV 1/3; 89/100] START max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=600
# [CV 3/3; 85/100] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=0.965 total time=  23.8s
# [CV 2/3; 89/100] START max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=600
# [CV 3/3; 86/100] END max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=0.965 total time=  14.1s
# [CV 3/3; 89/100] START max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=600
# [CV 2/3; 85/100] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=0.964 total time=  24.8s
# [CV 1/3; 90/100] START max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200
# [CV 3/3; 87/100] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400;, score=0.968 total time=   9.4s
# [CV 2/3; 90/100] START max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200
# [CV 1/3; 88/100] END max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600;, score=0.947 total time=  11.9s
# [CV 3/3; 90/100] START max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200
# [CV 2/3; 90/100] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.947 total time=   3.6s
# [CV 1/3; 91/100] START max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000
# [CV 1/3; 90/100] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.942 total time=   3.7s
# [CV 2/3; 91/100] START max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000
# [CV 1/3; 89/100] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=600;, score=0.898 total time=   7.5s
# [CV 3/3; 91/100] START max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000
# [CV 3/3; 90/100] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.949 total time=   3.5s
# [CV 1/3; 92/100] START max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600
# [CV 2/3; 89/100] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=600;, score=0.898 total time=   7.6s
# [CV 2/3; 92/100] START max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600
# [CV 3/3; 89/100] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=600;, score=0.905 total time=   7.5s
# [CV 3/3; 92/100] START max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600
# [CV 2/3; 88/100] END max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600;, score=0.954 total time=  13.0s
# [CV 1/3; 93/100] START max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400
# [CV 3/3; 88/100] END max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600;, score=0.955 total time=  12.6s
# [CV 2/3; 93/100] START max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400
# [CV 1/3; 93/100] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400;, score=0.900 total time=   5.3s
# [CV 3/3; 93/100] START max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400
# [CV 2/3; 93/100] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400;, score=0.892 total time=   5.2s
# [CV 1/3; 94/100] START max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800
# [CV 2/3; 92/100] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=0.915 total time=   9.4s
# [CV 2/3; 94/100] START max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800
# [CV 1/3; 92/100] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=0.908 total time=  10.0s
# [CV 3/3; 94/100] START max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800
# [CV 3/3; 92/100] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600;, score=0.916 total time=   9.2s
# [CV 1/3; 95/100] START max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000
# [CV 3/3; 93/100] END max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400;, score=0.903 total time=   5.1s
# [CV 2/3; 95/100] START max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000
# [CV 1/3; 91/100] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=0.913 total time=  16.5s
# [CV 2/3; 91/100] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=0.914 total time=  16.3s
# [CV 3/3; 95/100] START max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000
# [CV 1/3; 96/100] START max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400
# [CV 3/3; 91/100] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=0.914 total time=  15.6s
# [CV 2/3; 96/100] START max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400
# [CV 1/3; 96/100] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.907 total time=   7.2s
# [CV 3/3; 96/100] START max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400
# [CV 2/3; 96/100] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.905 total time=   6.0s
# [CV 1/3; 97/100] START max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000
# [CV 1/3; 94/100] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800;, score=0.957 total time=  13.9s
# [CV 2/3; 97/100] START max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000
# [CV 2/3; 94/100] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800;, score=0.963 total time=  15.1s
# [CV 3/3; 97/100] START max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000
# [CV 3/3; 94/100] END max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=800;, score=0.961 total time=  15.6s
# [CV 1/3; 98/100] START max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600
# [CV 3/3; 96/100] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.901 total time=   7.3s
# [CV 2/3; 98/100] START max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600
# [CV 1/3; 95/100] END max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=0.957 total time=  19.6s
# [CV 3/3; 98/100] START max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600
# [CV 2/3; 95/100] END max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=0.961 total time=  19.5s
# [CV 1/3; 99/100] START max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400
# [CV 3/3; 95/100] END max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=1000;, score=0.964 total time=  19.1s
# [CV 2/3; 99/100] START max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400
# [CV 1/3; 97/100] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.884 total time=  12.5s
# [CV 3/3; 99/100] START max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400
# [CV 2/3; 97/100] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.885 total time=  12.3s
# [CV 1/3; 100/100] START max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000
# [CV 3/3; 97/100] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.894 total time=  12.0s
# [CV 2/3; 100/100] START max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000
# [CV 1/3; 98/100] END max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600;, score=0.950 total time=  13.7s
# [CV 3/3; 100/100] START max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000
# [CV 2/3; 99/100] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.972 total time=   7.9s
# [CV 1/3; 99/100] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.973 total time=   8.7s
# [CV 3/3; 99/100] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.974 total time=   8.4s
# [CV 2/3; 98/100] END max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600;, score=0.955 total time=  13.8s
# [CV 3/3; 98/100] END max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600;, score=0.956 total time=  12.9s
# [CV 1/3; 100/100] END max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000;, score=0.957 total time=  13.8s
# [CV 2/3; 100/100] END max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000;, score=0.962 total time=  12.9s
# [CV 3/3; 100/100] END max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1000;, score=0.961 total time=  11.1s
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [10, 20, 30, 40, 50],
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [200, 400, 600, 800,
#                                                          1000]},
#                    random_state=42, verbose=10)

# %%
# Test the best model on the test set
best_model = cv.best_estimator_
y_pred = best_model.predict(X_test)

# %%
# Confusion matrix and classification report
# Tabulate the confusion matrix and write that columns are the predicted values and rows are the true values
conf = confusion_matrix(y_test, y_pred)
print('\n\nConfusion matrix\n')
print(tabulate(conf, headers=['Predicted 0', 'Predicted 1'], showindex=['True 0', 'True 1'], tablefmt='pretty'))

# Print the classification report
print('\n\nClassification report\n')
print(classification_report(y_test, y_pred))
# Out:
# Confusion matrix
#
# +--------+-------------+-------------+
# |        | Predicted 0 | Predicted 1 |
# +--------+-------------+-------------+
# | True 0 |    3618     |     144     |
# | True 1 |     211     |     27      |
# +--------+-------------+-------------+
#
#
# Classification report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95      3762
#            1       0.16      0.11      0.13       238
#
#     accuracy                           0.91      4000
#    macro avg       0.55      0.54      0.54      4000
# weighted avg       0.90      0.91      0.90      4000

# %%
#Print the best parameters
cv.best_params_
# Out:
# {'n_estimators': 600,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 50}

# %%
# Get the feature importances
feature_importances = best_model.feature_importances_
# Print the feature importances sorted by importance
print('\n\nFeature importances\n')
print(tabulate(sorted(zip(X_train.columns, feature_importances), key=lambda x: x[1], reverse=True), headers=['Feature', 'Importance'], tablefmt='pretty'))
# Out:
# Feature importances
#
# +------------+------------------------+
# |  Feature   |       Importance       |
# +------------+------------------------+
# |  PPERSAUT  |  0.10401701539903879   |
# |   PBRAND   |  0.07627526004755099   |
# |  PWAPART   |  0.038675459533560705  |
# |  MKOOPKLA  |  0.02937235273746822   |
# |  MINKM30   |  0.026702529097447456  |
# |  MINKGEM   |  0.026065226282519796  |
# |   MHHUUR   |  0.02571056266253889   |
# |  MBERARBG  |  0.024719920517648777  |
# |   MAUT1    |  0.024698223233668732  |
# |   MRELGE   |  0.024418504247675173  |
# |  MINK4575  |  0.02368482736759701   |
# |   MGODPR   |  0.023463184616985076  |
# |  MBERMIDD  |  0.02328950333020787   |
# |  MINK3045  |  0.023029317627660716  |
# |    MSKC    |  0.02267656801430249   |
# |  MOPLMIDD  |  0.02228639246226223   |
# |  MFGEKIND  |  0.021168190999645897  |
# |  MZFONDS   |  0.02047551916319861   |
# |  MBERARBO  |  0.020308002930281677  |
# |  MOPLHOOG  |  0.020100557251212542  |
# |  MBERHOOG  |  0.019759553175919063  |
# |    MSKA    |  0.01900012597683044   |
# |   MSKB2    |  0.018711129798978574  |
# |   MSKB1    |  0.018112927832580342  |
# |    MSKD    |  0.017807758810966644  |
# |   MAUT2    |  0.016538603023879748  |
# |  MINK7512  |  0.015576427312231885  |
# |   MGODOV   |  0.015275164903005557  |
# |   MGODRK   |  0.014005784993140594  |
# |   MRELSA   |  0.013378273961211867  |
# |  MBERBOER  |  0.013002846499794435  |
# |  MGEMOMV   |  0.012302675865098507  |
# |  MGEMLEEF  |  0.012227671101475483  |
# |   PLEVEN   |  0.011623785382553542  |
# |  PPLEZIER  |  0.01088221229587136   |
# |   PBROM    |  0.01016498477339546   |
# |  MBERZELF  |  0.008968272230592628  |
# |  PBYSTAND  |  0.008153992160046176  |
# |  PMOTSCO   |  0.007572633138687945  |
# |   PFIETS   |  0.007177133468880993  |
# | MOSTYPE.8  |  0.007010092326386859  |
# |  MINK123M  |  0.006479013935798467  |
# | MOSTYPE.36 |  0.006336165912040721  |
# | MOSTYPE.33 |  0.006032546846711212  |
# |  MAANTHUI  |  0.005911334841756946  |
# | MOSTYPE.38 |  0.005708977630125118  |
# | MOSTYPE.32 | 0.0039009628461945333  |
# | MOSTYPE.3  | 0.0038521604481558526  |
# | MOSTYPE.10 | 0.0036326847670227567  |
# | MOSTYPE.39 |  0.003380846305465975  |
# |  PTRACTOR  | 0.0032177427669281213  |
# | MOSTYPE.13 | 0.0028004821242598537  |
# | MOSTYPE.35 |  0.002794230676884087  |
# | MOSTYPE.9  |  0.002784133462191642  |
# | MOSTYPE.41 |  0.00274747869735587   |
# | MOSTYPE.11 |  0.002496877637171131  |
# |  PWAOREG   | 0.0024477823206156095  |
# |  PWABEDR   | 0.0023057359136198206  |
# |  PGEZONG   | 0.0022596747575421897  |
# | MOSTYPE.6  |  0.002246420683339139  |
# |  PWALAND   | 0.0022159246022378115  |
# | MOSTYPE.12 |  0.002188942841638633  |
# |  PINBOED   | 0.0021227709247713944  |
# | MOSTYPE.34 |  0.002115747003096173  |
# |  PAANHANG  |  0.001989987623772629  |
# | MOSTYPE.37 | 0.0019313044205390639  |
# | MOSTYPE.23 | 0.0018737887512565816  |
# | MOSTYPE.31 | 0.0018562300427931548  |
# | MOSTYPE.1  |  0.00153192586315662   |
# |  PBESAUT   | 0.0014418701179584159  |
# | MOSTYPE.2  | 0.0012444484759097708  |
# | MOSTYPE.24 |  0.001114641882385334  |
# | MOSTYPE.7  | 0.0009178863306679256  |
# | MOSTYPE.5  | 0.0008799991560521542  |
# | MOSTYPE.40 |  0.000858054688049756  |
# | MOSTYPE.25 | 0.0008062595516966136  |
# | MOSTYPE.22 | 0.0008035782787950544  |
# | MOSTYPE.30 | 0.0007458591728779757  |
# | MOSTYPE.4  | 0.0007095563216898096  |
# |  PPERSONG  | 0.0007050597823252198  |
# | MOSTYPE.20 | 0.0005660690687533581  |
# | MOSTYPE.29 |  0.000536681226353551  |
# | MOSTYPE.27 |  0.000280778755734104  |
# | MOSTYPE.26 | 0.00027731034480621517 |
# |  PZEILPL   | 0.00025111703955882857 |
# |   PWERKT   |  8.87037580692867e-05  |
# | MOSTYPE.28 | 7.527814299258424e-05  |
# | MOSTYPE.17 | 4.8383646604063255e-05 |
# | MOSTYPE.18 | 3.584605309986733e-05  |
# |  PVRAAUT   | 2.5925830371100595e-05 |
# | MOSTYPE.21 | 1.336392421986307e-05  |
# | MOSTYPE.16 | 1.2821571282317553e-05 |
# | MOSTYPE.19 | 6.982788792016181e-06  |
# | MOSTYPE.15 | 2.482890513898622e-06  |
# +------------+------------------------+

# %%
# Fit a decision tree using only the first 5 most important features
from sklearn.tree import DecisionTreeClassifier
# Get the 5 most important features
top5_features = [x[0] for x in sorted(zip(X_train.columns, feature_importances), key=lambda x: x[1], reverse=True)[:10]]
# Fit the model
tree = DecisionTreeClassifier()
tree.fit(X_train[top5_features], y_train)
# Get the predictions
y_pred_tree = tree.predict(X_test[top5_features])
# Confusion matrix and classification report
# Tabulate the confusion matrix and write that columns are the predicted values and rows are the true values
conf_tree = confusion_matrix(y_test, y_pred_tree)
print('\n\nConfusion matrix for the decision tree\n')
print(tabulate(conf_tree, headers=['Predicted 0', 'Predicted 1'], showindex=['True 0', 'True 1'], tablefmt='pretty'))
print('\n\nClassification report for the decision tree\n')
print(classification_report(y_test, y_pred_tree))
# Out:
# Confusion matrix for the decision tree
#
# +--------+-------------+-------------+
# |        | Predicted 0 | Predicted 1 |
# +--------+-------------+-------------+
# | True 0 |    3456     |     306     |
# | True 1 |     197     |     41      |
# +--------+-------------+-------------+
#
#
# Classification report for the decision tree
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      3762
#            1       0.12      0.17      0.14       238
#
#     accuracy                           0.87      4000
#    macro avg       0.53      0.55      0.54      4000
# weighted avg       0.90      0.87      0.89      4000
